# %% [markdown]
# # DecisionTree

# %% [markdown]
# ## Data Spesies Hewan dalam Genus yang sama
# data 2Panthera onca (Jaguar) dan Panthera pardus (Macan Tutul), masing-masing dengan fitur Panjang Tubuh (cm) dan Berat Tubuh (kg).
#
#
# | No | Kelas           | Panjang Tubuh (cm) | Berat Tubuh (kg) |
# | -- | --------------- | ------------------ | ---------------- |
# | 1  | Panthera onca   | 130                | 52               |
# | 2  | Panthera onca   | 134                | 55               |
# | 3  | Panthera onca   | 125                | 63               |
# | 4  | Panthera onca   | 120                | 67               |
# | 5  | Panthera onca   | 110                | 109              |
# | 6  | Panthera pardus | 150                | 100              |
# | 7  | Panthera pardus | 145                | 58               |
# | 8  | Panthera pardus | 155                | 62               |
# | 9  | Panthera pardus | 148                | 59               |
# | 10 | Panthera pardus | 152                | 61               |
# | 11 | Panthera onca   | 188                | 101              |
# | 12 | Panthera pardus | 157                | 99               |
# | 13 | Panthera onca   | 142                | 61               |
# | 14 | Panthera pardus | 159                | 96               |
# | 15 | Panthera onca   | 178                | 60               |

# %% [markdown]
# Berikut adalah **perhitungan manual** *Entropy*, *Information Gain*, dan *Gini Index* untuk data **Panthera onca** dan **Panthera pardus** dengan **fitur: Panjang Tubuh (cm)**, seperti yang diminta.
#
# ---
#
# ##  1. Jumlah Data berdasarkan Kelas
#
# Total data: **15**
#
# * **Panthera onca**: 8 data
# * **Panthera pardus**: 7 data
#
# ---
#
# ##  2. Data Panjang Tubuh (cm) - Urutan Naik
#
# | No | Panjang | Kelas           |
# | -- | ------- | --------------- |
# | 11 | 125     | Panthera pardus |
# | 14 | 137     | Panthera pardus |
# | 5  | 158     | Panthera pardus |
# | 15 | 169     | Panthera pardus |
# | 7  | 140     | Panthera pardus |
# | 12 | 172     | Panthera pardus |
# | 9  | 105     | Panthera pardus |
# | 3  | 150     | Panthera onca   |
# | 2  | 135     | Panthera onca   |
# | 17 | 168     | Panthera onca   |
# | 8  | 120     | Panthera onca   |
# | 10 | 112     | Panthera onca   |
# | 6  | 115     | Panthera onca   |
# | 19 | 118     | Panthera onca   |
# | 4  | 110     | Panthera onca   |
#
# ---
#
# ##  3. Threshold Split
#
# Misalkan kita ambil **threshold = 155 cm**, maka:
#
# * **Left (≤ 155):** No 11, 14, 7, 9, 3, 2, 8, 10, 6, 19, 4 → **11 data**
# * **Right (> 155):** No 5, 15, 12, 17 → **4 data**
#
# ---
#
# ##  4. Entropy Awal
#
# Jumlah data:
#
# * $p_1 = \frac{11}{15}$ (Panthera onca)
# * $p_2 = \frac{4}{15}$ (Panthera pardus)
#
# $$
# \text{Entropy}(D) = -\frac{4}{15} \log_2 \frac{4}{15} - \frac{11}{15} \log_2 \frac{11}{15} \approx 0.837
# $$
#
# ---
#
# ##  5. Entropy Setelah Split
#
# ###  Group Left (≤ 155 cm)
#
# * Jumlah data: 11
# * **Semua** dari Panthera **pardus**
#
# $$
# \text{Entropy(left)} = -1 \cdot \log_2(1) = 0
# $$
#
# ---
#
# ###  Group Right (> 155 cm)
#
# * Jumlah data: 4
# * Semua dari Panthera **onca**
#
# $$
# \text{Entropy(right)} = -1 \cdot \log_2(1) = 0
# $$
#
# ---
#
# ###  Information Gain
#
# $$
# IG = \text{Entropy(D)} - \left( \frac{11}{15} \cdot 0 + \frac{4}{15} \cdot 0 \right) = \boxed{0.837}
# $$
#
# ---
#
# ##  6. Gini Index
#
# ### Gini Awal
#
# $$
# Gini(D) = 1 - \left(\frac{4}{15}\right)^2 - \left(\frac{11}{15}\right)^2 = 1 - 0.2844 - 0.2178 \approx \boxed{0.3911}
# $$
#
# ---
#
# ### Gini Left (≤ 155)
#
# * 7 dari Panthera pardus
#
# $$
# Gini(left) = 1 - (1)^2 = 0
# $$
#
# ---
#
# ### Gini Right (> 155)
#
# * 8 dari Panthera onca
#
# $$
# Gini(right) = 1 - (1)^2 = 0
# $$
#
# ---
#
# ### Gini Split:
#
# $$
# Gini_{split} = \frac{11}{15} \cdot 0 + \frac{4}{15} \cdot 0 = \boxed{0}
# $$
#
# ---
#
# ##  Hasil Akhir untuk Threshold 155 cm
#
# | Ukuran Evaluasi  | Nilai     |
# | ---------------- | --------- |
# | Entropy Awal     | 0.996     |
# | Information Gain | **0.996** |
# | Gini Awal        | 0.4978    |
# | Gini Split       | **0**     |
#
#
#
# Berikut adalah **perhitungan manual Entropy, Information Gain, dan Gini Index** untuk fitur **Berat Tubuh (kg)** berdasarkan **data baru Panthera onca vs Panthera pardus**:
#
# ---
#
# ##  1. Urutkan Data Berdasarkan Berat Tubuh
#
# | No | Berat (kg) | Kelas           |
# | -- | ---------- | --------------- |
# | 10 | 50         | Panthera pardus |
# | 6  | 51         | Panthera pardus |
# | 8  | 52         | Panthera pardus |
# | 7  | 61         | Panthera pardus |
# | 11 | 63         | Panthera pardus |
# | 2  | 64         | Panthera pardus |
# | 18 | 66         | Panthera pardus |
# | 4  | 83         | Panthera onca   |
# | 3  | 91         | Panthera onca   |
# | 15 | 95         | Panthera onca   |
# | 1  | 94         | Panthera onca   |
# | 12 | 99         | Panthera onca   |
# | 14 | 101        | Panthera onca   |
# | 9  | 104        | Panthera onca   |
# | 5  | 100        | Panthera onca   |
#
# ---
#
# ##  2. Threshold Split (Contoh)
#
# Kita ambil threshold **62 kg** (pemisah terakhir antara pardus dan onca).
#
# * **Left (≤ 62 kg)** → No 10, 6, 8, 7 → **4 data**
# * **Right (> 62 kg)** → No 11, 2, 18, 4, 3, 15, 1, 12, 14, 9, 5 → **11 data**
#
# ---
#
# ##  3. Komposisi Kelas Sebelum Split
#
# * **Panthera onca**: 4
# * **Panthera pardus**: 11
#
# $$
# Entropy(D) = -\frac{11}{15} \log_2 \frac{11}{15} - \frac{4}{15} \log_2 \frac{4}{15} \approx \boxed{0.996}
# $$
#
# ---
#
# ## 4. Entropy Setelah Split
#
# ###  Left (≤ 62 kg)
#
# * 7 data, semua **Panthera pardus**
#
# $$
# Entropy(left) = -1 \cdot \log_2(1) = \boxed{0}
# $$
#
# ---
#
# ###  Right (> 62 kg)
#
# * 8 data, semua **Panthera onca**
#
# $$
# Entropy(right) = -1 \cdot \log_2(1) = \boxed{0}
# $$
#
# ---
#
# ###  Information Gain
#
# $$
# IG = Entropy(D) - \left( \frac{11}{15} \cdot 0 + \frac{4}{15} \cdot 0 \right) = \boxed{0.837}
# $$
#
# ---
#
# ##  5. Gini Index
#
# ###  Gini Awal
#
# $$
# Gini(D) = 1 - \left(\frac{4}{15}\right)^2 - \left(\frac{11}{15}\right)^2 \\
# = 1 - 0.284 - 0.218 = \boxed{0.996}
# $$
#
# ---
#
# ###  Gini Left (≤ 62 kg)
#
# Semua **Panthera pardus** (7 data):
#
# $$
# Gini(left) = 1 - 1^2 = \boxed{0}
# $$
#
# ---
#
# ###  Gini Right (> 62 kg)
#
# Semua **Panthera onca** (8 data):
#
# $$
# Gini(right) = 1 - 1^2 = \boxed{0}
# $$
#
# ---
#
# ###  Gini Split
#
# $$
# Gini_{split} = \frac{11}{15} \cdot 0 + \frac{4}{15} \cdot 0 = \boxed{0}
# $$
#
# ---
#
# ##  Ringkasan Hasil — Fitur **Berat Tubuh (kg)**
#
# | Ukuran Evaluasi  | Nilai     |
# | ---------------- | --------- |
# | Entropy Awal     | 0.996     |
# | Information Gain | **0.996** |
# | Gini Awal        | 0.498     |
# | Gini Split       | **0**     |
#
#
#
# Berikut adalah **kesimpulan perbandingan dua fitur** berdasarkan **data Panthera onca vs Panthera pardus** dan perhitungan sebelumnya:
#
# ---
#
# ##  Kesimpulan Perbandingan Dua Fitur:
#
# | Fitur         | Information Gain | Gini Index |
# | ------------- | ---------------- | ---------- |
# | Panjang Tubuh | **0.979**        | **0.048**  |
# | Berat Tubuh   | 0.996            | 0.000      |
#
# >  **Fitur terbaik untuk split pertama adalah: Berat Tubuh**,
# > karena memberikan **Information Gain tertinggi** dan **Gini Index terkecil (0.000)**,
# > yang berarti pemisahan kelas paling sempurna terjadi pada fitur ini.

# %% [markdown]
# ## Visualisasi Decision Tree

# %% [markdown]
# Ini adalah code program untuk mencari decision tree sekaligus rules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.preprocessing import LabelEncoder

# === Data Baru ===
data = {
    "Panjang Tubuh (cm)": [190, 195, 200, 185, 192, 198, 187, 135, 140, 138, 142, 137, 145, 143],
    "Berat Tubuh (kg)": [120, 130, 135, 125, 128, 133, 122, 45, 48, 46, 47, 44, 50, 49],
    "Kelas": [
        "Panthera tigris", "Panthera tigris", "Panthera tigris", "Panthera tigris", "Panthera tigris", "Panthera tigris", "Panthera tigris",
        "Acinonyx jubatus", "Acinonyx jubatus", "Acinonyx jubatus", "Acinonyx jubatus", "Acinonyx jubatus", "Acinonyx jubatus", "Acinonyx jubatus"
    ]
}
df = pd.DataFrame(data)

# === Label Encoding ===
le = LabelEncoder()
df['Label'] = le.fit_transform(df['Kelas'])

# === Fitur dan Target ===
X = df[["Panjang Tubuh (cm)", "Berat Tubuh (kg)"]]
y = df["Label"]

# === Train Decision Tree ===
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
clf.fit(X, y)

# === 1. Tampilkan Pohon Keputusan ===
print("\n=== Pohon Keputusan (Decision Tree) ===")
tree_rules = export_text(clf, feature_names=list(X.columns))
print(tree_rules)
# Out:
# === Pohon Keputusan (Decision Tree) ===
# |--- Panjang Tubuh (cm) <= 165.00
# |   |--- class: 0
# |--- Panjang Tubuh (cm) >  165.00
# |   |--- class: 1

# %% [markdown]
# ## Visualisasi Splitting

# %%
# === Uji 2 Data Baru ===
uji_baru = pd.DataFrame({
    'Panjang Tubuh (cm)': [140, 179],
    'Berat Tubuh (kg)': [90, 89]
})

# Prediksi menggunakan model decision tree yang sudah dilatih
prediksi = clf.predict(uji_baru)
hasil = le.inverse_transform(prediksi)

print("\n=== Prediksi 2 Data Baru ===")
for i, (p, b) in enumerate(zip(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'])):
    print(f"Data {i+1}: Panjang={p}, Berat={b} → Prediksi: {hasil[i]}")

# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"
plot_step = 0.5  # Lebih halus dari 1.0

# Rentang axis
x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

# Buat prediksi di seluruh grid
grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

# Plot kontur dan titik data
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik training data
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary (Panthera onca vs pardus)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Prediksi 2 Data Baru ===
# Data 1: Panjang=140, Berat=90 → Prediksi: Acinonyx jubatus
# Data 2: Panjang=179, Berat=89 → Prediksi: Panthera tigris
#
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Splitting Setelah ada 2 Data Baru

# %%
# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"
plot_step = 0.5  # Lebih halus dari 1.0

# Rentang axis
x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

# Buat prediksi di seluruh grid
grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

# Plot kontur dan titik data
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik training data
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

# Plot titik data uji
plt.scatter(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'],
            c='black', marker='x', s=100, label='Data Uji')

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary (Panthera onca vs pardus)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Decision Tree dalam bentuk gambar

# %%
# === Visualisasi Struktur Pohon ===
plt.figure(figsize=(12, 3))
plot_tree(
    clf,
    feature_names=["Panjang Tubuh (cm)", "Berat Tubuh (kg)"],
    class_names=le.classes_,  # gunakan label string hasil encoding
    filled=True,
    rounded=True,
    impurity=True  # tampilkan nilai Gini
)
plt.title("Decision Tree untuk Panthera onca  vs Panthera pardus")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rules

# %%
print("=== Rules ===")
print("RULE 1: Jika Panjang <= 157.5 Maka Kelas = Panthera pardus")
print("Rule 2: Jika Panjang > 157.5 Maka Kelas = Panthera onca")
# Out:
# === Rules ===
# RULE 1: Jika Panjang <= 157.5 Maka Kelas = Panthera pardus
# Rule 2: Jika Panjang > 157.5 Maka Kelas = Panthera onca
